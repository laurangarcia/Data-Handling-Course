# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
# %run ./pandas-missing-extension.ipynb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\nbformat\__init__.py:169, in read(fp, as_version, capture_validation_error, **kwargs)
#     168 try:
# --> 169     buf = fp.read()
#     170 except AttributeError:
#
# AttributeError: 'WindowsPath' object has no attribute 'read'
#
# During handling of the above exception, another exception occurred:
#
# NBFormatError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 get_ipython().run_line_magic('run', './pandas-missing-extension.ipynb')
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\IPython\core\magics\execution.py:749, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     747     with preserve_keys(self.shell.user_ns, '__file__'):
#     748         self.shell.user_ns['__file__'] = filename
# --> 749         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     750     return
#     752 # Control the response to exit() calls made by the script being run
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\IPython\core\interactiveshell.py:2992, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2990 with prepended_to_syspath(dname):
#    2991     try:
# -> 2992         for cell in get_cells():
#    2993             result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2994             if raise_exceptions:
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\IPython\core\interactiveshell.py:2981, in InteractiveShell.safe_execfile_ipy.<locals>.get_cells()
#    2979 if fname.suffix == ".ipynb":
#    2980     from nbformat import read
# -> 2981     nb = read(fname, as_version=4)
#    2982     if not nb.cells:
#    2983         return
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\nbformat\__init__.py:172, in read(fp, as_version, capture_validation_error, **kwargs)
#     170 except AttributeError:
#     171     with open(fp, encoding="utf8") as f:  # noqa: PTH123
# --> 172         return reads(f.read(), as_version, capture_validation_error, **kwargs)
#     174 return reads(buf, as_version, capture_validation_error, **kwargs)
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\nbformat\__init__.py:92, in reads(s, as_version, capture_validation_error, **kwargs)
#      66 def reads(s, as_version, capture_validation_error=None, **kwargs):
#      67     """Read a notebook from a string and return the NotebookNode object as the given version.
#      68
#      69     The string can contain a notebook of any version.
#    (...)     90         The notebook that was read.
#      91     """
# ---> 92     nb = reader.reads(s, **kwargs)
#      93     if as_version is not NO_CONVERT:
#      94         nb = convert(nb, as_version)
#
# File c:\Users\Admin\Documents\manejo_datos\Data-Handling-Course\venv\Lib\site-packages\nbformat\reader.py:84, in reads(s, **kwargs)
#      82         raise ValidationError(msg) from None
#      83 else:
# ---> 84     raise NBFormatError("Unsupported nbformat version %s" % major)
#
# NBFormatError: Unsupported nbformat version 4

# %%
df.missing.missing_variale_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.missing.missing_variale_plot()
#
# AttributeError: 'MissingMethods' object has no attribute 'missing_variale_plot'

# %%
(
    df
    .missing
    .missing_upsetplot(
        variables = None,
        element_size = 60
    )
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 (
#       2     df
#       3     .missing
# ----> 4     .missing_upsetplot(
#       5         variables = None,
#       6         element_size = 60
#       7     )
#       8 )
#
# AttributeError: 'MissingMethods' object has no attribute 'missing_upsetplot'

# %%
df[df.columns[1:6]].replace(0, np.nan)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0      148.0           72.0           35.0      NaN  33.6
# 1       85.0           66.0           29.0      NaN  26.6
# 2      183.0           64.0            NaN      NaN  23.3
# 3       89.0           66.0           23.0     94.0  28.1
# 4      137.0           40.0           35.0    168.0  43.1
# ..       ...            ...            ...      ...   ...
# 763    101.0           76.0           48.0    180.0  32.9
# 764    122.0           70.0           27.0      NaN  36.8
# 765    121.0           72.0           23.0    112.0  26.2
# 766    126.0           60.0            NaN      NaN  30.1
# 767     93.0           70.0           31.0      NaN  30.4
#
# [768 rows x 5 columns]

# %%
df.missing.missing_variable_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.missing.missing_variable_plot()
#
# AttributeError: 'MissingMethods' object has no attribute 'missing_variable_plot'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from upsetplot import plot as upsetplot_plot

@pd.api.extensions.register_dataframe_accessor("missing")
class MissingMethods:
    def __init__(self, pandas_obj):
        self._obj = pandas_obj

    def number_missing(self) -> int:
        return self._obj.isna().sum().sum()

    def number_complete(self) -> int:
        return self._obj.size - self._obj.missing.number_missing()

    def missing_variable_summary(self) -> pd.DataFrame:
        return self._obj.isnull().pipe(
            lambda df_1: (
                df_1.sum()
                .reset_index(name="n_missing")
                .rename(columns={"index": "variable"})
                .assign(
                    n_cases=len(df_1),
                    pct_missing=lambda df_2: df_2.n_missing / df_2.n_cases * 100,
                )
            )
        )

    def missing_case_summary(self) -> pd.DataFrame:
        return self._obj.assign(
            case=lambda df: df.index,
            n_missing=lambda df: df.apply(
                axis="columns", func=lambda row: row.isna().sum()
            ),
            pct_missing=lambda df: df["n_missing"] / df.shape[1] * 100,
        )[["case", "n_missing", "pct_missing"]]

    def missing_variable_table(self) -> pd.DataFrame:
        return (
            self._obj.missing.missing_variable_summary()
            .value_counts("n_missing")
            .reset_index(name="n_variables")
            .rename(columns={"n_missing": "n_missing_in_variable"})
            .assign(
                pct_variables=lambda df: df.n_variables / df.n_variables.sum() * 100
            )
            .sort_values("pct_variables", ascending=False)
        )

    def missing_case_table(self) -> pd.DataFrame:
        return (
            self._obj.missing.missing_case_summary()
            .value_counts("n_missing")
            .reset_index(name="n_cases")
            .rename(columns={"n_missing": "n_missing_in_case"})
            .assign(pct_case=lambda df: df.n_cases / df.n_cases.sum() * 100)
            .sort_values("pct_case", ascending=False)
        )

    def missing_variable_span(self, variable: str, span_every: int) -> pd.DataFrame:
        df = self._obj.copy()
        df["span_counter"] = np.floor(np.arange(df.shape[0]) / span_every).astype(int)

        return (
            df
            .groupby("span_counter")
            .aggregate(
                n_in_span=(variable, "size"),
                n_missing=(variable, lambda s: s.isnull().sum()),
            )
            .assign(
                n_complete=lambda df: df.n_in_span - df.n_missing,
                pct_missing=lambda df: df.n_missing / df.n_in_span * 100,
                pct_complete=lambda df: 100 - df.pct_missing,
            )
            .drop(columns=["n_in_span"])
            .reset_index()
        )

    def missing_variable_run(self, variable) -> pd.DataFrame:
        rle_list = self._obj[variable].pipe(
            lambda s: [[len(list(g)), k] for k, g in itertools.groupby(s.isnull())]
        )

        return pd.DataFrame(data=rle_list, columns=["run_length", "is_na"]).replace(
            {False: "complete", True: "missing"}
        )

    def sort_variables_by_missingness(self, ascending=False):
        return (
            self._obj
            .pipe(lambda df: df[df.isna().sum().sort_values(ascending=ascending).index])
        )

    def create_shadow_matrix(
        self,
        true_string: str = "Missing",
        false_string: str = "Not Missing",
        only_missing: bool = False,
    ) -> pd.DataFrame:
        shadow_df = self._obj.isna().replace({True: true_string, False: false_string})
        
        if only_missing:
            shadow_df = shadow_df.loc[:, self._obj.isna().any()]
        
        # Agrega el sufijo '_NA' a cada columna para diferenciar
        shadow_df.columns = [f"{col}_NA" for col in shadow_df.columns]
        return shadow_df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14304\2846392680.py:8: UserWarning: registration of accessor <class '__main__.MissingMethods'> under name 'missing' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   @pd.api.extensions.register_dataframe_accessor("missing")
